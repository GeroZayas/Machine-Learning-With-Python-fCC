# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
iris = pd.read_csv('https://sololearn.com/uploads/files/iris.csv')

# %%
iris.groupby("species").count()
# Out:
#                  id  sepal_len  sepal_wd  petal_len  petal_wd
# species
# iris-setosa      50         50        50         50        50
# iris-versicolor  50         50        50         50        50
# iris-virginica   50         50        50         50        50

# %%
iris.groupby("species").describe()
# Out:
#                    id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# species
# iris-setosa      50.0   24.5  14.57738    0.0   12.25   24.5   36.75   49.0
# iris-versicolor  50.0   74.5  14.57738   50.0   62.25   74.5   86.75   99.0
# iris-virginica   50.0  124.5  14.57738  100.0  112.25  124.5  136.75  149.0
#
#                 sepal_len         ... petal_len      petal_wd         \
#                     count   mean  ...       75%  max    count   mean
# species                           ...
# iris-setosa          50.0  5.006  ...     1.575  1.9     50.0  0.246
# iris-versicolor      50.0  5.936  ...     4.600  5.1     50.0  1.326
# iris-virginica       50.0  6.588  ...     5.875  6.9     50.0  2.026
#
#
#                       std  min  25%  50%  75%  max
# species
# iris-setosa      0.105386  0.1  0.2  0.2  0.3  0.6
# iris-versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# iris-virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# [3 rows x 40 columns]

# %%
iris[["species"]].describe()
# Out:
#             species
# count           150
# unique            3
# top     iris-setosa
# freq             50

# %%
iris.drop("id", axis=1, inplace=True)

# %%
iris
# Out:
#      sepal_len  sepal_wd  petal_len  petal_wd         species
# 0          5.1       3.5        1.4       0.2     iris-setosa
# 1          4.9       3.0        1.4       0.2     iris-setosa
# 2          4.7       3.2        1.3       0.2     iris-setosa
# 3          4.6       3.1        1.5       0.2     iris-setosa
# 4          5.0       3.6        1.4       0.2     iris-setosa
# ..         ...       ...        ...       ...             ...
# 145        6.7       3.0        5.2       2.3  iris-virginica
# 146        6.3       2.5        5.0       1.9  iris-virginica
# 147        6.5       3.0        5.2       2.0  iris-virginica
# 148        6.2       3.4        5.4       2.3  iris-virginica
# 149        5.9       3.0        5.1       1.8  iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.groupby("species").describe()
# Out:
#                 sepal_len                                              \
#                     count   mean       std  min    25%  50%  75%  max
# species
# iris-setosa          50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# iris-versicolor      50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# iris-virginica       50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 sepal_wd         ... petal_len      petal_wd                   \
#                    count   mean  ...       75%  max    count   mean       std
# species                          ...
# iris-setosa         50.0  3.428  ...     1.575  1.9     50.0  0.246  0.105386
# iris-versicolor     50.0  2.770  ...     4.600  5.1     50.0  1.326  0.197753
# iris-virginica      50.0  2.974  ...     5.875  6.9     50.0  2.026  0.274650
#
#
#                  min  25%  50%  75%  max
# species
# iris-setosa      0.1  0.2  0.2  0.3  0.6
# iris-versicolor  1.0  1.2  1.3  1.5  1.8
# iris-virginica   1.4  1.8  2.0  2.3  2.5
#
# [3 rows x 32 columns]

# %%
iris.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_len'}>,
#         <Axes: title={'center': 'sepal_wd'}>],
#        [<Axes: title={'center': 'petal_len'}>,
#         <Axes: title={'center': 'petal_wd'}>]], dtype=object)

# %%
iris[["sepal_len"]].hist()
# Out:
# array([[<Axes: title={'center': 'sepal_len'}>]], dtype=object)

# %%
# build a dict mapping species to an integer code
inv_name_dict = {'iris-setosa': 0,
'iris-versicolor': 1,
'iris-virginica': 2}

# %%
inv_name_dict
# Out:
# {'iris-setosa': 0, 'iris-versicolor': 1, 'iris-virginica': 2}

# %%
# build integer color code 0/1/2
colors = [inv_name_dict[item] for item in iris['species']]

# %%
scatter = plt.scatter(iris["sepal_len"], iris["sepal_wd"], c = colors)
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.legend(handles=scatter.legend_elements()[0],
labels = inv_name_dict.keys())
plt.show()
