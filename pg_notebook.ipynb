# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
barcelona_rent_price_DataFrame = pd.read_csv("./assets/Barcelona_rent_price.csv")

# %%
bar_rent_price_df = barcelona_rent_price_DataFrame # ALIAS

# %%
bar_rent_price_df
# Out:
#       Year  Trimester      District  \
# 0     2014          1  Ciutat Vella
# 1     2014          1  Ciutat Vella
# 2     2014          1  Ciutat Vella
# 3     2014          1  Ciutat Vella
# 4     2014          1      Eixample
# ...    ...        ...           ...
# 4617  2022          2    Sant Marti
# 4618  2022          2    Sant Marti
# 4619  2022          2    Sant Marti
# 4620  2022          2    Sant Marti
# 4621  2022          2    Sant Marti
#
#                                      Neighbourhood  \
# 0                                         el Raval
# 1                                   Gothic Quarter
# 2                                   la Barceloneta
# 3            Sant Pere, Santa Caterina i la Ribera
# 4                                       Fort Pienc
# ...                                            ...
# 4617  Diagonal Mar i el Front Maritim del Poblenou
# 4618                         el Besos i el Maresme
# 4619                       Provencals del Poblenou
# ...

# %%
bar_rent_price_df.describe()
# Out:
#               Year    Trimester        Price
# count  4622.000000  4622.000000  4622.000000
# mean   2017.745565     2.440502   416.457594
# std       2.462828     1.116377   442.872305
# min    2014.000000     1.000000     3.180000
# 25%    2016.000000     1.000000    12.100000
# 50%    2018.000000     2.000000    81.820000
# 75%    2020.000000     3.000000   777.207500
# max    2022.000000     4.000000  2034.000000

# %%
bar_rent_price_df.isna().count()
# Out:
# Year             4622
# Trimester        4622
# District         4622
# Neighbourhood    4622
# Average _rent    4622
# Price            4622
# dtype: int64

# %%
bar_rent_price_df[["District"]].value_counts()
# Out:
# District
# Nou Barris             714
# Horta-Guinardo         682
# Sant Marti             680
# Sants-Montjuic         486
# Sant Andreu            428
# Eixample               408
# Sarria-Sant Gervasi    408
# Gracia                 340
# Ciutat Vella           272
# Les Corts              204
# Name: count, dtype: int64

# %%
bar_rent_price_df.sample(20)
# Out:
#       Year  Trimester        District                       Neighbourhood  \
# 3976  2021          2          Gracia  el Camp d'en Grassot i Gracia Nova
# 1626  2016          4      Nou Barris                        la Guineueta
# 103   2014          2  Horta-Guinardo                           el Carmel
# 2852  2019          1      Nou Barris                    la Trinitat Nova
# 3357  2020          1  Sants-Montjuic                          la Bordeta
# 4369  2022          1       Les Corts                           les Corts
# 1804  2017          3       Les Corts                           les Corts
# 4234  2021          4       Les Corts          la Maternitat i Sant Ramon
# 2260  2018          1      Sant Marti             Provencals del Poblenou
# 2818  2019          1  Sants-Montjuic                       Sants - Badal
# 1179  2016          2  Sants-Montjuic                        el Poble Sec
# 4006  2021          2      Sant Marti   el Parc i la Llacuna del Poblenou
# ...

# %%
bar_rent_price_df.groupby(by="District").count().sort_values(by="Price", ascending=False)
# Out:
#                      Year  Trimester  Neighbourhood  Average _rent  Price
# District
# Nou Barris            714        714            714            714    714
# Horta-Guinardo        682        682            682            682    682
# Sant Marti            680        680            680            680    680
# Sants-Montjuic        486        486            486            486    486
# Sant Andreu           428        428            428            428    428
# Eixample              408        408            408            408    408
# Sarria-Sant Gervasi   408        408            408            408    408
# Gracia                340        340            340            340    340
# Ciutat Vella          272        272            272            272    272
# Les Corts             204        204            204            204    204

# %%
bar_rent_price_df.drop(["Year", "Trimester"], axis=1).groupby(by="District").describe()
# Out:
#                      Price                                                   \
#                      count        mean         std    min      25%      50%
# District
# Ciutat Vella         272.0  424.533971  423.531366   9.84  14.2000  281.005
# Eixample             408.0  488.028652  488.417276   9.64  13.3550  339.215
# Gracia               340.0  418.870235  415.894955   8.85  12.9800  276.375
# Horta-Guinardo       682.0  361.227625  358.742093   7.62  11.6000  191.600
# Les Corts            204.0  605.114804  653.902659  10.02  14.1000  348.600
# Nou Barris           714.0  303.694496  305.237996   3.54  10.0750   79.275
# Sant Andreu          428.0  339.932103  343.308502   3.18  10.7650   77.770
# Sant Marti           680.0  438.496368  453.019780   6.84  12.4975  222.175
# Sants-Montjuic       486.0  378.624033  376.980186   3.90  12.3925  182.900
# Sarria-Sant Gervasi  408.0  621.431152  629.589842   6.25  14.8875  385.725
#
#
#                            75%     max
# ...

# %%
#bar_rent_price_df.drop(["Year", "Trimester"], axis=1).groupby(by="District").hist(column="Price", bins=10, legend=True)

# %%
bar_rent_price_df.drop(["Year", "Trimester"], axis=1).hist()
plt.show()

# %%
bar_rent_price_df[["Price"]].hist(bins=15)
# Out:
# array([[<Axes: title={'center': 'Price'}>]], dtype=object)

# %%
bar_rent_price_df.plot(kind="scatter",x ="District", y="Price", figsize=(12,6), color="r")
plt.show()

# %%
bar_rent_price_df[["Price"]].dtypes
# Out:
# Price    float64
# dtype: object

# %%
bar_rent_price_df.dtypes
# Out:
# Year               int64
# Trimester          int64
# District          object
# Neighbourhood     object
# Average _rent     object
# Price            float64
# dtype: object
